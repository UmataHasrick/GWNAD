# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(0, 1, 0.1), np.arange(0, 1, 0.1))

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from torch import nn, optim

# %%
from scipy import stats
import time
from sklearn.metrics import auc

# %%
epochs = 200
rTrain = 0.7;
rTest = 0.2;
# input_vector_length = 100
batch_size = 32
num_bins = 40
coef_delta = 0

# %%
# epochs = 400
# test_sample_ratio = .2
# validation_sample_ratio = 0.1
# batch_size = 32
# coef_delta = 0

# noise_ratio = 0.9
# bbh_ratio = 0.1

# %%
def upperTPRFPRcalc(trainerror, signalerror, FPRlist):
    TPRlist = np.zeros(len(FPRlist))
    length_of_train_sample = len(trainerror)
    print(length_of_train_sample)
    length_of_signal_value = len(signalerror)
    print(length_of_signal_value)
    
    for i in range(len(FPRlist)):
        index_number = int(length_of_train_sample * FPRlist[i])
        threshold = np.sort(trainerror)[-index_number]
            
        # print(threshold)
        # print(np.argwhere(signalerror >= threshold).shape)
        TPRlist[i] = np.argwhere(signalerror > threshold).shape[0] / length_of_signal_value
    
    TPRlist[-1] = 1
    
    return TPRlist

def lowerTPRFPRcalc(trainerror, signalerror, FPRlist):
    TPRlist = np.zeros(len(FPRlist))
    length_of_train_sample = len(trainerror)
    # print(length_of_train_sample)
    length_of_signal_value = len(signalerror)
    # print(length_of_signal_value)
    
    for i in range(len(FPRlist)):
        index_number = int(length_of_train_sample * FPRlist[i])
        if index_number == 0:
            threshold = np.sort(trainerror)[index_number]
        else:
            threshold = np.sort(trainerror)[index_number-1]
        # print(np.sort(trainerror))
        # print(threshold)
        # print(np.argwhere(signalerror < threshold).shape)
        TPRlist[i] = np.argwhere(signalerror < threshold).shape[0] / length_of_signal_value
    
    TPRlist[-1] = 1
    
    return TPRlist

FPR_list = np.logspace(-3,0,100)

# %% [markdown]
# ## Data preparation

# %%
renorm_factor = 20;

realbkg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/background.npz")['data'] / renorm_factor;
realbbh = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/bbh_for_challenge.npy") / renorm_factor;

realsg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/sglf_for_challenge.npy") / renorm_factor;

# %%
realglitch = np.load("../Data_cached/real_glitches_snrlt5_60132_4000Hz_25ms.npz")["strain_time_data"] / 12.3

# %% [markdown]
# We only care about pattern, so we center each input to 0 by subtracting its mean, and renormalize by dividing over $\sigma$

# %%
realbkg_trimmed = realbkg[:, 0];
realbbh_trimmed = realbbh[:, 0];
realsg_trimmed  = realsg[:, 0];

realbkg_trimmed = (realbkg_trimmed - np.transpose([np.mean(realbkg_trimmed, axis=1)]))/np.transpose([np.std(realbkg_trimmed, axis=1)]);
realbbh_trimmed = (realbbh_trimmed - np.transpose([np.mean(realbbh_trimmed, axis=1)]))/np.transpose([np.std(realbbh_trimmed, axis=1)]);
realsg_trimmed  = (realsg_trimmed  - np.transpose([np.mean(realsg_trimmed , axis=1)]))/np.transpose([np.std(realsg_trimmed,  axis=1)]);

# %%
realglitch_trimmed = (realglitch - np.transpose([np.mean(realglitch, axis=1)]))/np.transpose([np.std(realglitch, axis=1)])

# %%
dInput = realbkg_trimmed.shape[1]

# %%
# nTotal = len(bkg);
nTotal = len(realbbh_trimmed);
nTrain = int(rTrain * nTotal)
nTest  = int(rTest * nTotal)
nValid = nTotal - nTrain - nTest;

nTrain_g = int(rTrain * len(realglitch_trimmed))
nTest_g  = int(rTest  * len(realglitch_trimmed))
nValid_g = len(realglitch_trimmed) - nTrain_g - nTest_g;

X_train = np.empty((3*nTrain + nTrain_g, dInput))
X_test  = np.empty((3*nTest + nTest_g,  dInput))
X_valid = np.empty((3*nValid + nValid_g, dInput))

target_train = np.zeros((3*nTrain + nTrain_g,), dtype="int64")
target_test  = np.zeros((3*nTest + nTest_g, ), dtype="int64")
target_valid = np.zeros((3*nValid + nValid_g,), dtype="int64")

# permBKG = np.random.permutation(nTotal)
# permBBH = np.random.permutation(nTotal)
# permSG  = np.random.permutation(nTotal)
# permGLITCH = np.random.permutation(len(realglitch_trimmed))

# np.savetxt("../Data_cached/SupLearn/perm_BKG.dat", permBKG)
# np.savetxt("../Data_cached/SupLearn/perm_BBH.dat", permBBH)
# np.savetxt("../Data_cached/SupLearn/perm_SG.dat", permSG)
# np.savetxt("../Data_cached/SupLearn/perm_GLITCH.dat", permGLITCH)


permBKG = np.genfromtxt("../Data_cached/SupLearn/perm_BKG.dat").astype(int)
permBBH = np.genfromtxt("../Data_cached/SupLearn/perm_BBH.dat").astype(int)
permSG = np.genfromtxt("../Data_cached/SupLearn/perm_SG.dat").astype(int)
permGLITCH = np.genfromtxt("../Data_cached/SupLearn/perm_GLITCH.dat").astype(int)

# initializing the training set
X_train[:nTrain] = realbkg_trimmed[permBKG[:nTrain]]
X_train[nTrain:2*nTrain] = realbbh_trimmed[permBBH[:nTrain]]
X_train[2*nTrain:3*nTrain] = realsg_trimmed[permSG[:nTrain]]
X_train[3*nTrain:] = realglitch_trimmed[permGLITCH[:nTrain_g]]

target_train[:nTrain] = 1;
target_train[nTrain:2*nTrain] = 2;
target_train[2*nTrain:3*nTrain] = 3;

# initializing the test set
X_test[:nTest] = realbkg_trimmed[permBKG[-nTest:]]
X_test[nTest:2*nTest] = realbbh_trimmed[permBBH[-nTest:]]
X_test[2*nTest:3*nTest] = realsg_trimmed[permSG[-nTest:]]
X_test[3*nTest:] = realglitch_trimmed[permGLITCH[-nTest_g:]]

target_test[:nTest] = 1;
target_test[nTest:2*nTest] = 2;
target_test[2*nTest:3*nTest] = 3;

# initializing the validation set
X_valid[:nValid] = realbkg_trimmed[permBKG[nTrain:-nTest]]
X_valid[nValid:2*nValid] = realbbh_trimmed[permBBH[nTrain:-nTest]]
X_valid[2*nValid:3*nValid] = realsg_trimmed[permSG[nTrain:-nTest]]
X_valid[3*nValid:] = realglitch_trimmed[permGLITCH[nTrain_g:-nTest_g]]

target_valid[:nValid] = 1;
target_valid[nValid:2*nValid] = 2;
target_valid[2*nValid:3*nValid] = 3;

train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.tensor(target_train))
test_dataset  = TensorDataset(torch.FloatTensor(X_test),  torch.tensor(target_test))
valid_dataset = TensorDataset(torch.FloatTensor(X_valid), torch.tensor(target_valid))

trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validationDataLoader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=True)

# X_train = realbbh_trimmed[perm[:nTrain]]
# X_test = realbbh_trimmed[perm[-nTest:]]
# X_validation = realbbh_trimmed[perm[nTrain:-nTest]]

# trainData = torch.FloatTensor(X_train)
# testData = torch.FloatTensor(X_test)
# validationData = torch.FloatTensor(X_validation)

# train_dataset = TensorDataset(trainData, trainData)
# test_dataset = TensorDataset(testData, testData)
# validation_dataset = TensorDataset(validationData, validationData)

# trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# validationDataLoader = DataLoader(dataset=validation_dataset, batch_size=batch_size, shuffle = True)

# %%
# # nTotal = len(bkg);
# nTotal = len(realbbh_trimmed);
# nTrain = int(rTrain * nTotal)
# nTest  = int(rTest * nTotal)
# nValid = nTotal - nTrain - nTest;

# nTrain_g = int(rTrain * len(realglitch_trimmed))
# nTest_g  = int(rTest  * len(realglitch_trimmed))
# nValid_g = len(realglitch_trimmed) - nTrain_g - nTest_g;

# X_train = np.empty((2*nTrain + nTrain_g, dInput))
# X_test  = np.empty((3*nTest + nTest_g,  dInput))
# X_valid = np.empty((2*nValid + nValid_g, dInput))

# target_train = np.zeros((2*nTrain + nTrain_g,), dtype="int64")
# target_test  = np.zeros((3*nTest + nTest_g, ), dtype="int64")
# target_valid = np.zeros((2*nValid + nValid_g,), dtype="int64")

# # permBKG = np.random.permutation(nTotal)
# # permBBH = np.random.permutation(nTotal)
# # permSG  = np.random.permutation(nTotal)
# # permGLITCH = np.random.permutation(len(realglitch_trimmed))

# # np.savetxt("../Data_cached/SupLearn/perm_BKG.dat", permBKG)
# # np.savetxt("../Data_cached/SupLearn/perm_BBH.dat", permBBH)
# # np.savetxt("../Data_cached/SupLearn/perm_SG.dat", permSG)
# # np.savetxt("../Data_cached/SupLearn/perm_GLITCH.dat", permGLITCH)

# permBKG = np.genfromtxt("../Data_cached/SupLearn/perm_BKG.dat").astype(int)
# permBBH = np.genfromtxt("../Data_cached/SupLearn/perm_BBH.dat").astype(int)
# permSG = np.genfromtxt("../Data_cached/SupLearn/perm_SG.dat").astype(int)
# permGLITCH = np.genfromtxt("../Data_cached/SupLearn/perm_GLITCH.dat").astype(int)


# # initializing the training set
# X_train[:nTrain] = realbkg_trimmed[permBKG[:nTrain]]
# X_train[nTrain:2*nTrain] = realbbh_trimmed[permBBH[:nTrain]]
# X_train[2*nTrain:3*nTrain] = realsg_trimmed[permSG[:nTrain]]
# X_train[3*nTrain:] = realglitch_trimmed[permGLITCH[:nTrain_g]]

# target_train[:nTrain] = 1;
# target_train[nTrain:2*nTrain] = 2;
# target_train[2*nTrain:] = 3;

# # initializing the test set
# X_test[:nTest] = realbkg_trimmed[permBKG[-nTest:]]
# X_test[nTest:2*nTest] = realbbh_trimmed[permBBH[-nTest:]]
# X_test[2*nTest:3*nTest] = realsg_trimmed[permSG[-nTest:]]
# X_test[3*nTest:] = realglitch_trimmed[permGLITCH[-nTest_g:]]

# target_test[:nTest] = 1;
# target_test[nTest:2*nTest] = 2;
# target_test[2*nTest:3*nTest] = 3;

# # initializing the validation set
# X_valid[:nValid] = realbkg_trimmed[permBKG[nTrain:-nTest]]
# X_valid[nValid:2*nValid] = realbbh_trimmed[permBBH[nTrain:-nTest]]
# X_valid[2*nValid:3*nValid] = realsg_trimmed[permSG[nTrain:-nTest]]
# X_valid[3*nValid:] = realglitch_trimmed[permGLITCH[nTrain_g:-nTest_g]]

# target_valid[:nValid] = 1;
# target_valid[nValid:2*nValid] = 2;
# target_valid[2*nValid:] = 3;

# train_dataset = TensorDataset(torch.FloatTensor(X_train), torch.tensor(target_train))
# test_dataset  = TensorDataset(torch.FloatTensor(X_test),  torch.tensor(target_test))
# valid_dataset = TensorDataset(torch.FloatTensor(X_valid), torch.tensor(target_valid))

# trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# validationDataLoader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=True)

# # X_train = realbbh_trimmed[perm[:nTrain]]
# # X_test = realbbh_trimmed[perm[-nTest:]]
# # X_validation = realbbh_trimmed[perm[nTrain:-nTest]]

# # trainData = torch.FloatTensor(X_train)
# # testData = torch.FloatTensor(X_test)
# # validationData = torch.FloatTensor(X_validation)

# # train_dataset = TensorDataset(trainData, trainData)
# # test_dataset = TensorDataset(testData, testData)
# # validation_dataset = TensorDataset(validationData, validationData)

# # trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
# # validationDataLoader = DataLoader(dataset=validation_dataset, batch_size=batch_size, shuffle = True)

# %% [markdown]
# ## Train the model

# %% [markdown]
# ### 200-256-64-16-4 overfits

# %%
class SLDNN(nn.Module):
    def __init__(self):
        super(SLDNN, self).__init__()
        self.fc1 = nn.Linear(200, 256)
        self.fc2 = nn.Linear(256, 64)
        self.fc3 = nn.Linear(64, 16)
        self.output = nn.Linear(16, 4)
        self.act = nn.ReLU()

    def forward(self, x):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.act(self.fc3(x))
        
        # CrossEntropyLoss apply softmax automatically
        return self.output(x)
    
#         x = self.sig(self.fc3(x))
#         return x

# %%
classifier = SLDNN().cuda()

print(sum(p.numel() for p in classifier.parameters() if p.requires_grad))

optimizer = optim.Adam(classifier.parameters(), lr=0.00005)
loss_func = nn.CrossEntropyLoss().cuda()
loss_train = np.empty((epochs, ))
loss_validation = np.empty((epochs, ))

for epoch in range(epochs):

    t0 = time.time()
    classifier.train()
    for batchidx, (x, tgt_index) in enumerate(trainDataLoader):
        x = x.cuda()
        tgt_index = tgt_index.cuda()
        output = classifier(x)
        loss = loss_func(output, tgt_index)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    classifier.eval()
    with torch.no_grad():
        val_loss = 0
        n_correct = 0;
        for batchidx, (x, tgt_index) in enumerate(validationDataLoader):
            x = x.cuda()
            tgt_index = tgt_index.cuda()
            output = classifier(x)
            lossVal = loss_func(output, tgt_index)
            val_loss += lossVal.item()
            n_correct += torch.eq(tgt_index, torch.argmax(output, dim=1)).sum().item()

        val_loss /= len(validationDataLoader)

    loss_train[epoch] = loss.item()
    loss_validation[epoch] = val_loss
    print('Epoch: %04d, Training loss=%f, Validation loss=%f, valid accuracy=%f' % (epoch+1, loss_train[epoch], val_loss, n_correct*1./len(X_valid)))
    print(time.time() - t0)

#     print(time.time() - t0)
torch.save(classifier.cuda(), "../data/SupLearn/Classifier.pt")
np.savetxt("../data/SupLearn/lossClassifierTraining.dat", [loss_train, loss_validation])
# Out:
# 69012
# Epoch: 0001, Training loss=0.716341, Validation loss=0.659474, valid accuracy=0.727525
# 22.961671829223633
# Epoch: 0002, Training loss=0.724929, Validation loss=0.591136, valid accuracy=0.760685
# 24.01495623588562
# Epoch: 0003, Training loss=1.565517, Validation loss=0.538217, valid accuracy=0.780491
# 20.58991241455078
# Epoch: 0004, Training loss=0.755785, Validation loss=0.484133, valid accuracy=0.801039
# 22.432342529296875
# Epoch: 0005, Training loss=0.428920, Validation loss=0.453784, valid accuracy=0.817716
# 21.063053607940674
# Epoch: 0006, Training loss=0.681117, Validation loss=0.429937, valid accuracy=0.828425
# 22.68608546257019
# Epoch: 0007, Training loss=0.755017, Validation loss=0.410904, valid accuracy=0.837521
# 20.667065382003784
# Epoch: 0008, Training loss=0.558902, Validation loss=0.389444, valid accuracy=0.846650
# 19.968596696853638
# Epoch: 0009, Training loss=0.081652, Validation loss=0.375257, valid accuracy=0.854005
# 22.784510612487793
# Epoch: 0010, Training loss=0.174944, Validation loss=0.363983, valid accuracy=0.862004
# 25.066428422927856
# Epoch: 0011, Training loss=0.456722, Validation loss=0.354264, valid accuracy=0.866359
# 23.824623346328735
# Epoch: 0012, Training loss=0.452162, Validation loss=0.345533, valid accuracy=0.869972
# 23.792800426483154
# Epoch: 0013, Training loss=0.130491, Validation loss=0.338289, valid accuracy=0.873294
# 22.3272123336792
# Epoch: 0014, Training loss=0.463073, Validation loss=0.333598, valid accuracy=0.876649
# 20.190425872802734
# Epoch: 0015, Training loss=0.366912, Validation loss=0.334552, valid accuracy=0.876327
# 22.19597887992859
# Epoch: 0016, Training loss=0.537483, Validation loss=0.331502, valid accuracy=0.878843
# 21.884100437164307
# Epoch: 0017, Training loss=0.613097, Validation loss=0.329724, valid accuracy=0.880197
# 20.035488843917847
# Epoch: 0018, Training loss=0.112838, Validation loss=0.329656, valid accuracy=0.880133
# 19.178800344467163
# Epoch: 0019, Training loss=0.017968, Validation loss=0.328490, valid accuracy=0.882036
# 21.097496271133423
# Epoch: 0020, Training loss=0.118792, Validation loss=0.328915, valid accuracy=0.883068
# 24.296005725860596
# Epoch: 0021, Training loss=0.034771, Validation loss=0.330580, valid accuracy=0.882197
# 23.939759969711304
# Epoch: 0022, Training loss=0.629982, Validation loss=0.332427, valid accuracy=0.882455
# 24.83075523376465
# Epoch: 0023, Training loss=0.054412, Validation loss=0.331640, valid accuracy=0.883326
# 24.650160789489746
# Epoch: 0024, Training loss=0.101042, Validation loss=0.334828, valid accuracy=0.882617
# 22.400179862976074
# Epoch: 0025, Training loss=0.538772, Validation loss=0.334853, valid accuracy=0.884101
# 16.62474822998047
# Epoch: 0026, Training loss=0.156575, Validation loss=0.339357, valid accuracy=0.884068
# 17.653285026550293
# 21.712652444839478
# Epoch: 0200, Training loss=0.000001, Validation loss=1.341131, valid accuracy=0.871133
# 24.229257106781006

# %%
plt.plot(loss_train)
plt.plot(loss_validation)

# %% [markdown]
# ### 200-128-64-16-4: better but still overfits

# %%
class SLDNN(nn.Module):
    def __init__(self):
        super(SLDNN, self).__init__()
        self.fc1 = nn.Linear(200, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 16)
        self.output = nn.Linear(16, 4)
        self.act = nn.ReLU()

    def forward(self, x):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.act(self.fc3(x))
        
        # CrossEntropyLoss apply softmax automatically
        return self.output(x)
    
#         x = self.sig(self.fc3(x))
#         return x

# %%
classifier = SLDNN().cuda()

print(sum(p.numel() for p in classifier.parameters() if p.requires_grad))

optimizer = optim.Adam(classifier.parameters(), lr=0.00005)
loss_func = nn.CrossEntropyLoss().cuda()
loss_train = np.empty((epochs, ))
loss_validation = np.empty((epochs, ))

for epoch in range(epochs):

    t0 = time.time()
    classifier.train()
    for batchidx, (x, tgt_index) in enumerate(trainDataLoader):
        x = x.cuda()
        tgt_index = tgt_index.cuda()
        output = classifier(x)
        loss = loss_func(output, tgt_index)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    classifier.eval()
    with torch.no_grad():
        val_loss = 0
        n_correct = 0;
        for batchidx, (x, tgt_index) in enumerate(validationDataLoader):
            x = x.cuda()
            tgt_index = tgt_index.cuda()
            output = classifier(x)
            lossVal = loss_func(output, tgt_index)
            val_loss += lossVal.item()
            n_correct += torch.eq(tgt_index, torch.argmax(output, dim=1)).sum().item()

        val_loss /= len(validationDataLoader)

    loss_train[epoch] = loss.item()
    loss_validation[epoch] = val_loss
    print('Epoch: %04d, Training loss=%f, Validation loss=%f, valid accuracy=%f' % (epoch+1, loss_train[epoch], val_loss, n_correct*1./len(X_valid)))
    print(time.time() - t0)

#     print(time.time() - t0)
torch.save(classifier.cuda(), "../data/SupLearn/Classifier.pt")
np.savetxt("../data/SupLearn/lossClassifierTraining.dat", [loss_train, loss_validation])
# Out:
# 35092
# Epoch: 0001, Training loss=0.395813, Validation loss=0.718931, valid accuracy=0.682817
# 21.692484617233276
# Epoch: 0002, Training loss=0.712611, Validation loss=0.648337, valid accuracy=0.726235
# 21.730019569396973
# Epoch: 0003, Training loss=0.354911, Validation loss=0.601300, valid accuracy=0.751847
# 20.64396905899048
# Epoch: 0004, Training loss=0.942349, Validation loss=0.558352, valid accuracy=0.766943
# 19.985103845596313
# Epoch: 0005, Training loss=0.688014, Validation loss=0.514905, valid accuracy=0.787329
# 20.99190378189087
# Epoch: 0006, Training loss=0.159022, Validation loss=0.488268, valid accuracy=0.798974
# 25.618062734603882
# Epoch: 0007, Training loss=0.238200, Validation loss=0.473634, valid accuracy=0.804587
# 23.176112413406372
# Epoch: 0008, Training loss=0.627101, Validation loss=0.463786, valid accuracy=0.810135
# 20.043574571609497
# Epoch: 0009, Training loss=0.098818, Validation loss=0.453601, valid accuracy=0.815329
# 19.42044949531555
# Epoch: 0010, Training loss=0.667101, Validation loss=0.443009, valid accuracy=0.821135
# Epoch: 0183, Training loss=0.013709, Validation loss=0.451236, valid accuracy=0.887713
# 19.4799485206604
# Epoch: 0184, Training loss=0.041216, Validation loss=0.449379, valid accuracy=0.889165
# 24.77934217453003
# Epoch: 0185, Training loss=0.023946, Validation loss=0.456891, valid accuracy=0.889165
# 21.734890699386597
# Epoch: 0186, Training loss=0.033019, Validation loss=0.459690, valid accuracy=0.887842
# 19.435144424438477
# Epoch: 0187, Training loss=0.154592, Validation loss=0.459307, valid accuracy=0.886939
# 19.97614622116089
# Epoch: 0188, Training loss=0.000165, Validation loss=0.461333, valid accuracy=0.889294
# 20.118988513946533
# Epoch: 0189, Training loss=0.130373, Validation loss=0.460575, valid accuracy=0.887939
# 20.562324047088623
# Epoch: 0190, Training loss=0.195243, Validation loss=0.460961, valid accuracy=0.889294
# 18.804828643798828
# Epoch: 0191, Training loss=0.333072, Validation loss=0.465538, valid accuracy=0.888971
# 18.452521800994873
# Epoch: 0192, Training loss=0.089399, Validation loss=0.462845, valid accuracy=0.887455
# 19.665229320526123
# Epoch: 0193, Training loss=0.206100, Validation loss=0.463957, valid accuracy=0.886488
# 20.347297191619873
# Epoch: 0194, Training loss=0.016444, Validation loss=0.469875, valid accuracy=0.884971
# 20.249194622039795
# Epoch: 0195, Training loss=0.089580, Validation loss=0.473161, valid accuracy=0.887875
# 20.68753743171692
# Epoch: 0196, Training loss=0.005624, Validation loss=0.469918, valid accuracy=0.886907
# 21.191036701202393
# Epoch: 0197, Training loss=0.006946, Validation loss=0.476142, valid accuracy=0.887649
# 23.2206814289093
# Epoch: 0198, Training loss=0.089888, Validation loss=0.465413, valid accuracy=0.888681
# 23.809348344802856
# Epoch: 0199, Training loss=0.200366, Validation loss=0.473123, valid accuracy=0.888262
# 24.130110025405884
# Epoch: 0200, Training loss=0.106448, Validation loss=0.472547, valid accuracy=0.887907
# 22.51639199256897

# %%
plt.plot(loss_train)
plt.plot(loss_validation)

# %% [markdown]
# ### 200-64-16-4

# %%
class SLDNN(nn.Module):
    def __init__(self):
        super(SLDNN, self).__init__()
        self.fc1 = nn.Linear(200, 64)
        self.fc2 = nn.Linear(64, 16)
#         self.fc3 = nn.Linear(64, 16)
        self.output = nn.Linear(16, 4)
        self.act = nn.ReLU()

    def forward(self, x):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
#         x = self.act(self.fc3(x))
        
        # CrossEntropyLoss apply softmax automatically
        return self.output(x)
    
#         x = self.sig(self.fc3(x))
#         return x

# %%
classifier = SLDNN().cuda()

print(sum(p.numel() for p in classifier.parameters() if p.requires_grad))

optimizer = optim.Adam(classifier.parameters(), lr=0.00005)
loss_func = nn.CrossEntropyLoss().cuda()
loss_train = np.empty((epochs, ))
loss_validation = np.empty((epochs, ))

for epoch in range(epochs):

    t0 = time.time()
    classifier.train()
    for batchidx, (x, tgt_index) in enumerate(trainDataLoader):
        x = x.cuda()
        tgt_index = tgt_index.cuda()
        output = classifier(x)
        loss = loss_func(output, tgt_index)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    classifier.eval()
    with torch.no_grad():
        val_loss = 0
        n_correct = 0;
        for batchidx, (x, tgt_index) in enumerate(validationDataLoader):
            x = x.cuda()
            tgt_index = tgt_index.cuda()
            output = classifier(x)
            lossVal = loss_func(output, tgt_index)
            val_loss += lossVal.item()
            n_correct += torch.eq(tgt_index, torch.argmax(output, dim=1)).sum().item()

        val_loss /= len(validationDataLoader)

    loss_train[epoch] = loss.item()
    loss_validation[epoch] = val_loss
    print('Epoch: %04d, Training loss=%f, Validation loss=%f, valid accuracy=%f' % (epoch+1, loss_train[epoch], val_loss, n_correct*1./len(X_valid)))
    print(time.time() - t0)

#     print(time.time() - t0)
torch.save(classifier.cuda(), "../data/SupLearn/Classifier.pt")
np.savetxt("../data/SupLearn/lossClassifierTraining.dat", [loss_train, loss_validation])
# Out:
# 13972
# Epoch: 0001, Training loss=1.456019, Validation loss=0.786205, valid accuracy=0.644721
# 18.16793918609619
# Epoch: 0002, Training loss=0.650406, Validation loss=0.697365, valid accuracy=0.692591
# 21.656566619873047
# Epoch: 0003, Training loss=0.233004, Validation loss=0.660391, valid accuracy=0.713590
# 20.478137016296387
# Epoch: 0004, Training loss=0.493061, Validation loss=0.630474, valid accuracy=0.730622
# 22.07361149787903
# Epoch: 0005, Training loss=0.812376, Validation loss=0.604382, valid accuracy=0.745363
# 20.356573343276978
# Epoch: 0006, Training loss=0.136681, Validation loss=0.580074, valid accuracy=0.756556
# 20.248222827911377
# Epoch: 0007, Training loss=1.263927, Validation loss=0.559727, valid accuracy=0.765620
# 20.941830158233643
# Epoch: 0008, Training loss=0.834122, Validation loss=0.543950, valid accuracy=0.772265
# 22.41158962249756
# Epoch: 0009, Training loss=0.511720, Validation loss=0.530675, valid accuracy=0.778265
# 20.44349694252014
# Epoch: 0010, Training loss=0.186668, Validation loss=0.522152, valid accuracy=0.781846
# 21.727680444717407
# Epoch: 0011, Training loss=0.970428, Validation loss=0.513645, valid accuracy=0.787168
# 19.708205938339233
# Epoch: 0012, Training loss=0.415813, Validation loss=0.506021, valid accuracy=0.789975
# 20.274966716766357
# Epoch: 0013, Training loss=0.163446, Validation loss=0.497811, valid accuracy=0.793555
# 24.553694009780884
# Epoch: 0014, Training loss=0.345692, Validation loss=0.491472, valid accuracy=0.796265
# 20.650142908096313
# Epoch: 0015, Training loss=0.093224, Validation loss=0.483119, valid accuracy=0.800232
# 20.33214259147644
# Epoch: 0016, Training loss=0.377423, Validation loss=0.476560, valid accuracy=0.803393
# 19.858214139938354
# Epoch: 0017, Training loss=0.455488, Validation loss=0.472458, valid accuracy=0.806426
# 18.590721368789673
# Epoch: 0018, Training loss=0.089095, Validation loss=0.467588, valid accuracy=0.807135
# 17.923879384994507
# Epoch: 0019, Training loss=0.360857, Validation loss=0.463490, valid accuracy=0.811425
# 17.54528498649597
# Epoch: 0020, Training loss=0.344209, Validation loss=0.458298, valid accuracy=0.812909
# 16.498860359191895
# Epoch: 0021, Training loss=0.230935, Validation loss=0.454484, valid accuracy=0.816167
# 16.615935802459717
# Epoch: 0022, Training loss=0.430496, Validation loss=0.450034, valid accuracy=0.817393
# Epoch: 0195, Training loss=0.041060, Validation loss=0.350103, valid accuracy=0.872940
# 17.336062908172607
# Epoch: 0196, Training loss=0.234908, Validation loss=0.350848, valid accuracy=0.872294
# 16.286561489105225
# Epoch: 0197, Training loss=0.209581, Validation loss=0.350869, valid accuracy=0.872488
# 16.427182912826538
# Epoch: 0198, Training loss=0.398859, Validation loss=0.349987, valid accuracy=0.871811
# 18.391304969787598
# Epoch: 0199, Training loss=0.401440, Validation loss=0.350361, valid accuracy=0.872843
# 18.50418996810913
# Epoch: 0200, Training loss=0.153923, Validation loss=0.350363, valid accuracy=0.872456
# 18.05294132232666

# %%
plt.plot(loss_train)
plt.plot(loss_validation)

# %%
classifier.cpu()
# Out:
# SLDNN(
#   (fc1): Linear(in_features=200, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=4, bias=True)
#   (act): ReLU()
# )

# %%
X_train.shape
# Out:
# (216998, 200)

# %%
classifier = torch.load('../Model_cached/Classifier_64-16.pt').cpu()

# %%
outputTest = classifier(torch.FloatTensor(X_test))

# %%
resTest = torch.argmax(nn.Softmax(dim=1)(outputTest), dim=1).detach().numpy()

# %%
resTest_beforeSM = nn.Softmax(dim=1)(outputTest).detach().numpy()

# %% [markdown]
# #### Distribution of 4 channels, 200-64-16-4

# %%
bins = np.arange(0,1,0.01)

# %%
plt.hist(resTest_beforeSM[:nTest][:,0], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,0], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,0], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,0], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,1], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,1], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,1], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,1], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,2], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,2], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,2], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,2], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,3], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,3], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,3], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,3], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %% [markdown]
# #### Trying to remove channel

# %%
resTest_beforeSM = nn.Softmax(dim=1)(outputTest).detach().numpy()[:,[0,2,3]]

# %%
resTest_beforeSM = nn.Softmax(dim=1)(outputTest).detach().numpy()[:,[0,1,2]]

# %%
resTest_beforeSM = nn.Softmax(dim=1)(outputTest).detach().numpy()[:,[0,1,3]]

# %%
resTest_beforeSM = resTest_beforeSM / np.sum(resTest_beforeSM, axis = 1).reshape(-1,1)

# %%
np.array([[1,2,3],[1,2,3],[1,2,3]]) / np.array([[1],[2],[3]])
# Out:
# array([[1.        , 2.        , 3.        ],
#        [0.5       , 1.        , 1.5       ],
#        [0.33333333, 0.66666667, 1.        ]])

# %%
resTest_beforeSM.shape
# Out:
# (72026, 3)

# %%
resTest
# Out:
# tensor([1, 1, 1,  ..., 0, 1, 0])

# %%
target_test
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# #### Distribution of 3 channels, 200-64-16-4, sg as anomaly, exclude SG channel and normalized

# %%
resTest_beforeSM = nn.Softmax(dim=1)(outputTest).detach().numpy()[:,[0,1,2]]
resTest_beforeSM = resTest_beforeSM / np.sum(resTest_beforeSM, axis = 1).reshape(-1,1)

# %%
bins = np.arange(0,1,0.01)

# %%
plt.hist(resTest_beforeSM[:nTest][:,1], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,1], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,1], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,1], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,0], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,0], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,0], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,0], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(np.log(resTest_beforeSM[:nTest][:,0] + 1e-16), histtype='step', label = 'noise', bins = 50, density=True)
plt.hist(np.log(resTest_beforeSM[nTest : 2 * nTest][:,0] + 1e-16), histtype='step', label = 'BBH', bins = 50, density=True)
plt.hist(np.log(resTest_beforeSM[2 * nTest:3 * nTest][:,0] + 1e-16), histtype='step', label = 'sinegaussian', bins = 50, density=True)
plt.hist(np.log(resTest_beforeSM[3 * nTest:][:,2] + 1e-16), histtype='step', label = 'glitch', bins = 50, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,2], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,2], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,2], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,2], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(np.log(resTest_beforeSM[:nTest][:,2] + 1e-16), histtype='step', label = 'noise', bins = 50, density=True)
plt.hist(np.log(resTest_beforeSM[nTest : 2 * nTest][:,2] + 1e-16), histtype='step', label = 'BBH', bins = 50, density=True)
plt.hist(np.log(resTest_beforeSM[2 * nTest:3 * nTest][:,2] + 1e-16), histtype='step', label = 'sinegaussian', bins = 50, density=True)
# plt.hist(resTest_beforeSM[3 * nTest:][:,2], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %% [markdown]
# #### 3D probability distribution

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\471168039.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

ax1.scatter3D(resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] == 1).flatten()][:,0], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] == 1).flatten()][:,1], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] == 1).flatten()][:,2], s = 1, label = 'noise selected')
ax1.scatter3D(resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] != 1).flatten()][:,0], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] != 1).flatten()][:,1], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] != 1).flatten()][:,2], s = 1, label = 'noise not selected')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\2058859274.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\3047443841.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\3397659250.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\1475906022.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\132908402.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\471168039.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

ax1.scatter3D(resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] == 1).flatten()][:,0], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] == 1).flatten()][:,1], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] == 1).flatten()][:,2], s = 1, label = 'noise selected')
ax1.scatter3D(resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] != 1).flatten()][:,0], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] != 1).flatten()][:,1], resTest_beforeSM[:nTest][np.argwhere(resTest[:nTest] != 1).flatten()][:,2], s = 1, label = 'noise not selected')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\2058859274.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\3047443841.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
resTest_beforeSM_class = np.argmax(resTest_beforeSM, axis = 1)

# %%
np.argwhere(resTest_beforeSM_class[:nTest] == 1).shape[0]
# Out:
# 5094

# %%
np.argwhere(resTest_beforeSM_class[:nTest] == 0).shape[0]
# Out:
# 642

# %%
np.argwhere(resTest_beforeSM_class[:nTest] == 2).shape[0]
# Out:
# 14264

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\3397659250.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\1475906022.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\132908402.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
np.savetxt('../Data_cached/Sigmoid_200-64-16-4_without_noise_score.txt', resTest_beforeSM, fmt='%f')

# %% [markdown]
# ### Below we exclude the bbh score and see BBH as anomalies

# %% [markdown]
# #### Distribution of 3 channels, 200-64-16-4, bbh as anomaly, exclude BBH channel and normalized

# %%
bins = np.arange(0,1,0.01)

# %%
plt.hist(resTest_beforeSM[:nTest][:,0], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,0], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,0], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,0], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,1], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,1], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,1], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,1], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,2], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : 2 * nTest][:,2], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[2 * nTest:3 * nTest][:,2], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[3 * nTest:][:,2], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %% [markdown]
# #### 3D probability distribution

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\3047443841.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\3397659250.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
resTest_beforeSM_class = np.argmax(resTest_beforeSM, axis = 1)

# %%
np.argwhere(resTest_beforeSM_class[nTest:2 * nTest] == 0).shape[0]
# Out:
# 320

# %%
np.argwhere(resTest_beforeSM_class[nTest:2 * nTest] == 1).shape[0]
# Out:
# 8516

# %%
np.argwhere(resTest_beforeSM_class[nTest:2 * nTest] == 2).shape[0]
# Out:
# 11164

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
# ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\1475906022.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
ax1 = plt.axes(projection = '3d')

# ax1.scatter3D(resTest_beforeSM[:nTest][:,0], resTest_beforeSM[:nTest][:,1], resTest_beforeSM[:nTest][:,2], s = 1, label = 'noise')
# ax1.scatter3D(resTest_beforeSM[nTest:2*nTest][:,0], resTest_beforeSM[nTest:2*nTest][:,1], resTest_beforeSM[nTest:2*nTest][:,2], s = 1, label = 'bbh')
# ax1.scatter3D(resTest_beforeSM[2 * nTest:3 * nTest][:,0], resTest_beforeSM[2 * nTest:3 * nTest][:,1], resTest_beforeSM[2 * nTest:3 * nTest][:,2], s = 1, label = 'sinegaussian')
ax1.scatter3D(resTest_beforeSM[3 * nTest:][:,0], resTest_beforeSM[3 * nTest:][:,1], resTest_beforeSM[3 * nTest:][:,2], s = 1, label = 'glitch')
ax1.view_init(elev = 30, azim=45)

plt.legend()

fig.show()
# Out:
# C:\Users\Liyang Miao\AppData\Local\Temp\ipykernel_23288\132908402.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
print(torch.eq(torch.tensor(target_test), resTest).sum().item())
print(torch.eq(torch.tensor(target_test), resTest).sum().item() / len(target_test))
# Out:
# 64311
# 0.8928859023130536

# %%
print(len(target_test) - torch.eq(torch.tensor(target_test>1), resTest<=1).sum().item())
print(1 - torch.eq(torch.tensor(target_test>1), resTest<=1).sum().item() / len(target_test))
# Out:
# 65829
# 0.9139616249687613

# %% [markdown]
# ### Investigate the accuracy, for different propotion of the data, used to train the DNN AE and Andy's framework

# %% [markdown]
# #### BBH accuracy

# %%
renorm_factor = 20;

realbkg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/background.npz")['data'] / renorm_factor;
realbbh = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/bbh_for_challenge.npy") / renorm_factor;

realsg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/sglf_for_challenge.npy") / renorm_factor;
# realglitch = np.load("../data/real_glitches_9998_4000Hz_25ms.npz")["strain_time_data"]
realglitch = np.load("../Data_cached/real_glitches_snrlt5_60132_4000Hz_25ms.npz")["strain_time_data"] / 12.3

realbkg_trimmed = realbkg[:, 0];
realbbh_trimmed = realbbh[:, 0];
realsg_trimmed  = realsg[:, 0];

realbkg_trimmed = (realbkg_trimmed - np.transpose([np.mean(realbkg_trimmed, axis=1)]))/np.transpose([np.std(realbkg_trimmed, axis=1)]);
realbbh_trimmed = (realbbh_trimmed - np.transpose([np.mean(realbbh_trimmed, axis=1)]))/np.transpose([np.std(realbbh_trimmed, axis=1)]);
realsg_trimmed  = (realsg_trimmed  - np.transpose([np.mean(realsg_trimmed , axis=1)]))/np.transpose([np.std(realsg_trimmed,  axis=1)]);

realglitch_trimmed = (realglitch - np.transpose([np.mean(realglitch, axis=1)]))/np.transpose([np.std(realglitch, axis=1)])

dInput = realbkg_trimmed.shape[1]

nTotal = len(realbbh_trimmed);
nTrain = int(rTrain * nTotal)
nTest  = int(rTest * nTotal)
nValid = nTotal - nTrain - nTest;

nTrain_ns = int(0.4*nTrain)
nTest_ns = int(0.4*nTest)
nValid_ns = int(0.4*nValid)

nTrain_g = int(0.2*nTrain)
nTest_g = int(0.2*nTest)
nValid_g = int(0.2*nValid)

X_train = np.empty((nTrain + 2*nTrain_ns + nTrain_g, dInput))
X_test  = np.empty((nTest + 2*nTest_ns + nTest_g,  dInput))
X_valid = np.empty((nValid + 2*nValid_ns + nValid_g, dInput))

target_train = np.zeros((nTrain + 2*nTrain_ns + nTrain_g, ), dtype="int64")
target_test  = np.zeros((nTest + 2*nTest_ns + nTest_g, ), dtype="int64")
target_valid = np.zeros((nValid + 2*nValid_ns + nValid_g, ), dtype="int64")

# permBKG = np.random.permutation(nTotal)
# permBBH = np.random.permutation(nTotal)
# permSG  = np.random.permutation(nTotal)
# permGLITCH = np.random.permutation(len(realglitch_trimmed))

# np.savetxt("../Data_cached/SupLearn/permDNN_BKG.dat", permBKG)
# np.savetxt("../Data_cached/SupLearn/permDNN_BBH.dat", permBBH)
# np.savetxt("../Data_cached/SupLearn/permDNN_SG.dat", permSG)
# np.savetxt("../Data_cached/SupLearn/permDNN_GLITCH.dat", permGLITCH)

permBKG = np.genfromtxt("../Data_cached/SupLearn/permDNN_BKG.dat").astype(int)
permBBH = np.genfromtxt("../Data_cached/SupLearn/permDNN_BBH.dat").astype(int)
permSG = np.genfromtxt("../Data_cached/SupLearn/permDNN_SG.dat").astype(int)
permGLITCH = np.genfromtxt("../Data_cached/SupLearn/permDNN_GLITCH.dat").astype(int)

# initializing the training set
X_train[ : nTrain] = realbbh_trimmed[permBBH[:nTrain]]
X_train[nTrain : nTrain+nTrain_ns] = realbkg_trimmed[permBKG[:nTrain_ns]]
X_train[nTrain+nTrain_ns : nTrain+2*nTrain_ns] = realsg_trimmed[permSG[:nTrain_ns]]
X_train[nTrain+2*nTrain_ns : ] = realglitch_trimmed[permGLITCH[:nTrain_g]]

target_train[:nTrain] = 1;

# initializing the test set
X_test[ : nTest] = realbbh_trimmed[permBBH[-nTest:]]
X_test[nTest : nTest+nTest_ns] = realbkg_trimmed[permBKG[-nTest_ns:]]
X_test[nTest+nTest_ns : nTest+2*nTest_ns] = realsg_trimmed[permSG[-nTest_ns:]]
X_test[nTest+2*nTest_ns : ] = realglitch_trimmed[permGLITCH[-nTest_g:]]

target_test[:nTest] = 1;

# initializing the validation set
X_valid[:nValid] = realbbh_trimmed[permBBH[nTrain : -nTest]]
X_valid[nValid : nValid+nValid_ns] = realbkg_trimmed[permBKG[nTrain_ns : nTrain_ns+nValid_ns]]
X_valid[nValid+nValid_ns : nValid+2*nValid_ns] = realsg_trimmed[permSG[nTrain_ns : nTrain_ns+nValid_ns]]
X_valid[nValid+2*nValid_ns : ] = realglitch_trimmed[permGLITCH[nTrain_g : nTrain_g+nValid_g]]

target_valid[:nValid] = 1;

train_dataset = TensorDataset(torch.FloatTensor(X_train.reshape((X_train.shape[0], X_train.shape[1]))), torch.FloatTensor(target_train.reshape((len(target_train)),1)))
test_dataset  = TensorDataset(torch.FloatTensor(X_test.reshape((X_test.shape[0], X_test.shape[1]))),  torch.FloatTensor(target_test.reshape((len(target_test)),1)))
valid_dataset = TensorDataset(torch.FloatTensor(X_valid.reshape((X_valid.shape[0], X_valid.shape[1]))), torch.FloatTensor(target_valid.reshape((len(target_valid)),1)))

trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validationDataLoader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=True)

# %%
outputTest = classifier(torch.FloatTensor(X_test))
resTest = torch.argmax(nn.Softmax(dim=1)(outputTest), dim=1)
resTest_beforeSM = nn.Softmax(dim = 1)(outputTest).detach().numpy()

# %%
classifier
# Out:
# SLDNN(
#   (fc1): Linear(in_features=200, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=4, bias=True)
#   (act): ReLU()
# )

# %%
resTest
# Out:
# tensor([2, 2, 2,  ..., 0, 0, 0])

# %%
plt.hist(resTest_beforeSM[:nTest][:,2], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : nTest+nTest_ns][:,2], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+nTest_ns:nTest+2 * nTest_ns][:,2], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+2 * nTest_ns:][:,2], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,2], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : nTest+nTest_ns][:,2], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+nTest_ns:nTest+2 * nTest_ns][:,2], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+2 * nTest_ns:][:,2], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()
plt.show()

TPR_list = upperTPRFPRcalc(resTest_beforeSM[nTest:][:,2].flatten(), resTest_beforeSM[:nTest][:,2].flatten(), FPR_list)
plt.plot(FPR_list, TPR_list, label = 'auc = ' + str(auc(FPR_list, TPR_list)))
plt.xscale('log')
plt.ylim(0,1.1)
plt.legend()
plt.show()
# Out:
# 20000
# 20000

# %%
np.argwhere(resTest[:nTest] == 2).shape[1]
# Out:
# 18714

# %%
(np.argwhere(resTest[:nTest] == 2).shape[1] + np.argwhere(resTest[nTest:] != 2).shape[1]) / (2 * nTest)
# Out:
# 0.953575

# %% [markdown]
# #### SG accuracy

# %%
renorm_factor = 20;

realbkg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/background.npz")['data'] / renorm_factor;
realsg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/bbh_for_challenge.npy") / renorm_factor;

realbbh = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/sglf_for_challenge.npy") / renorm_factor;
# realglitch = np.load("../data/real_glitches_9998_4000Hz_25ms.npz")["strain_time_data"]
realglitch = np.load("../Data_cached/real_glitches_snrlt5_60132_4000Hz_25ms.npz")["strain_time_data"] / 12.3

realbkg_trimmed = realbkg[:, 0];
realbbh_trimmed = realbbh[:, 0];
realsg_trimmed  = realsg[:, 0];

realbkg_trimmed = (realbkg_trimmed - np.transpose([np.mean(realbkg_trimmed, axis=1)]))/np.transpose([np.std(realbkg_trimmed, axis=1)]);
realbbh_trimmed = (realbbh_trimmed - np.transpose([np.mean(realbbh_trimmed, axis=1)]))/np.transpose([np.std(realbbh_trimmed, axis=1)]);
realsg_trimmed  = (realsg_trimmed  - np.transpose([np.mean(realsg_trimmed , axis=1)]))/np.transpose([np.std(realsg_trimmed,  axis=1)]);

realglitch_trimmed = (realglitch - np.transpose([np.mean(realglitch, axis=1)]))/np.transpose([np.std(realglitch, axis=1)])

dInput = realbkg_trimmed.shape[1]

nTotal = len(realbbh_trimmed);
nTrain = int(rTrain * nTotal)
nTest  = int(rTest * nTotal)
nValid = nTotal - nTrain - nTest;

nTrain_ns = int(0.4*nTrain)
nTest_ns = int(0.4*nTest)
nValid_ns = int(0.4*nValid)

nTrain_g = int(0.2*nTrain)
nTest_g = int(0.2*nTest)
nValid_g = int(0.2*nValid)

X_train = np.empty((nTrain + 2*nTrain_ns + nTrain_g, dInput))
X_test  = np.empty((nTest + 2*nTest_ns + nTest_g,  dInput))
X_valid = np.empty((nValid + 2*nValid_ns + nValid_g, dInput))

target_train = np.zeros((nTrain + 2*nTrain_ns + nTrain_g, ), dtype="int64")
target_test  = np.zeros((nTest + 2*nTest_ns + nTest_g, ), dtype="int64")
target_valid = np.zeros((nValid + 2*nValid_ns + nValid_g, ), dtype="int64")

# permBKG = np.random.permutation(nTotal)
# permBBH = np.random.permutation(nTotal)
# permSG  = np.random.permutation(nTotal)
# permGLITCH = np.random.permutation(len(realglitch_trimmed))

# np.savetxt("../Data_cached/SupLearn/permDNN_BKG_1.dat", permBKG)
# np.savetxt("../Data_cached/SupLearn/permDNN_BBH_1.dat", permBBH)
# np.savetxt("../Data_cached/SupLearn/permDNN_SG_1.dat", permSG)
# np.savetxt("../Data_cached/SupLearn/permDNN_GLITCH_1.dat", permGLITCH)

permBKG = np.genfromtxt("../Data_cached/SupLearn/permDNN_BKG_1.dat").astype(int)
permBBH = np.genfromtxt("../Data_cached/SupLearn/permDNN_BBH_1.dat").astype(int)
permSG = np.genfromtxt("../Data_cached/SupLearn/permDNN_SG_1.dat").astype(int)
permGLITCH = np.genfromtxt("../Data_cached/SupLearn/permDNN_GLITCH_1.dat").astype(int)

# initializing the training set
X_train[ : nTrain] = realbbh_trimmed[permBBH[:nTrain]]
X_train[nTrain : nTrain+nTrain_ns] = realbkg_trimmed[permBKG[:nTrain_ns]]
X_train[nTrain+nTrain_ns : nTrain+2*nTrain_ns] = realsg_trimmed[permSG[:nTrain_ns]]
X_train[nTrain+2*nTrain_ns : ] = realglitch_trimmed[permGLITCH[:nTrain_g]]

target_train[:nTrain] = 1;

# initializing the test set
X_test[ : nTest] = realbbh_trimmed[permBBH[-nTest:]]
X_test[nTest : nTest+nTest_ns] = realbkg_trimmed[permBKG[-nTest_ns:]]
X_test[nTest+nTest_ns : nTest+2*nTest_ns] = realsg_trimmed[permSG[-nTest_ns:]]
X_test[nTest+2*nTest_ns : ] = realglitch_trimmed[permGLITCH[-nTest_g:]]

target_test[:nTest] = 1;

# initializing the validation set
X_valid[:nValid] = realbbh_trimmed[permBBH[nTrain : -nTest]]
X_valid[nValid : nValid+nValid_ns] = realbkg_trimmed[permBKG[nTrain_ns : nTrain_ns+nValid_ns]]
X_valid[nValid+nValid_ns : nValid+2*nValid_ns] = realsg_trimmed[permSG[nTrain_ns : nTrain_ns+nValid_ns]]
X_valid[nValid+2*nValid_ns : ] = realglitch_trimmed[permGLITCH[nTrain_g : nTrain_g+nValid_g]]

target_valid[:nValid] = 1;

train_dataset = TensorDataset(torch.FloatTensor(X_train.reshape((X_train.shape[0], X_train.shape[1]))), torch.FloatTensor(target_train.reshape((len(target_train)),1)))
test_dataset  = TensorDataset(torch.FloatTensor(X_test.reshape((X_test.shape[0], X_test.shape[1]))),  torch.FloatTensor(target_test.reshape((len(target_test)),1)))
valid_dataset = TensorDataset(torch.FloatTensor(X_valid.reshape((X_valid.shape[0], X_valid.shape[1]))), torch.FloatTensor(target_valid.reshape((len(target_valid)),1)))

trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validationDataLoader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=True)

# %%
outputTest = classifier(torch.FloatTensor(X_test))
resTest = torch.argmax(nn.Softmax(dim=1)(outputTest), dim=1)
resTest_beforeSM = nn.Softmax(dim = 1)(outputTest).detach().numpy()

# %%
classifier
# Out:
# SLDNN(
#   (fc1): Linear(in_features=200, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=4, bias=True)
#   (act): ReLU()
# )

# %%
resTest
# Out:
# tensor([3, 3, 3,  ..., 0, 0, 0])

# %%
plt.hist(resTest_beforeSM[:nTest][:,3], histtype='step', label = 'Sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : nTest+nTest_ns][:,3], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+nTest_ns:nTest+2 * nTest_ns][:,3], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+2 * nTest_ns:][:,3], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,3], histtype='step', label = 'Sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : nTest+nTest_ns][:,3], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+nTest_ns:nTest+2 * nTest_ns][:,3], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+2 * nTest_ns:][:,3], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()
plt.show()

TPR_list = upperTPRFPRcalc(resTest_beforeSM[nTest:][:,3].flatten(), resTest_beforeSM[:nTest][:,3].flatten(), FPR_list)
plt.plot(FPR_list, TPR_list, label = 'auc = ' + str(auc(FPR_list, TPR_list)))
plt.xscale('log')
plt.ylim(0,1.1)
plt.legend()
plt.show()
# Out:
# 20000
# 20000

# %%
np.argwhere(resTest[:nTest] == 3).shape[1]
# Out:
# 17307

# %%
(np.argwhere(resTest[:nTest] == 3).shape[1] + np.argwhere(resTest[nTest:] != 3).shape[1]) / (2 * nTest)
# Out:
# 0.915075

# %% [markdown]
# #### Noise accuracy

# %%
renorm_factor = 20;

realbbh = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/background.npz")['data'] / renorm_factor;
realbkg= np.load("E://GWNMMAD_data/Tw_dataset/Datasets/bbh_for_challenge.npy") / renorm_factor;

realsg = np.load("E://GWNMMAD_data/Tw_dataset/Datasets/sglf_for_challenge.npy") / renorm_factor;
# realglitch = np.load("../data/real_glitches_9998_4000Hz_25ms.npz")["strain_time_data"]
realglitch = np.load("../Data_cached/real_glitches_snrlt5_60132_4000Hz_25ms.npz")["strain_time_data"] / 12.3

realbkg_trimmed = realbkg[:, 0];
realbbh_trimmed = realbbh[:, 0];
realsg_trimmed  = realsg[:, 0];

realbkg_trimmed = (realbkg_trimmed - np.transpose([np.mean(realbkg_trimmed, axis=1)]))/np.transpose([np.std(realbkg_trimmed, axis=1)]);
realbbh_trimmed = (realbbh_trimmed - np.transpose([np.mean(realbbh_trimmed, axis=1)]))/np.transpose([np.std(realbbh_trimmed, axis=1)]);
realsg_trimmed  = (realsg_trimmed  - np.transpose([np.mean(realsg_trimmed , axis=1)]))/np.transpose([np.std(realsg_trimmed,  axis=1)]);

realglitch_trimmed = (realglitch - np.transpose([np.mean(realglitch, axis=1)]))/np.transpose([np.std(realglitch, axis=1)])

dInput = realbkg_trimmed.shape[1]

nTotal = len(realbbh_trimmed);
nTrain = int(rTrain * nTotal)
nTest  = int(rTest * nTotal)
nValid = nTotal - nTrain - nTest;

nTrain_ns = int(0.4*nTrain)
nTest_ns = int(0.4*nTest)
nValid_ns = int(0.4*nValid)

nTrain_g = int(0.2*nTrain)
nTest_g = int(0.2*nTest)
nValid_g = int(0.2*nValid)

X_train = np.empty((nTrain + 2*nTrain_ns + nTrain_g, dInput))
X_test  = np.empty((nTest + 2*nTest_ns + nTest_g,  dInput))
X_valid = np.empty((nValid + 2*nValid_ns + nValid_g, dInput))

target_train = np.zeros((nTrain + 2*nTrain_ns + nTrain_g, ), dtype="int64")
target_test  = np.zeros((nTest + 2*nTest_ns + nTest_g, ), dtype="int64")
target_valid = np.zeros((nValid + 2*nValid_ns + nValid_g, ), dtype="int64")

# permBKG = np.random.permutation(nTotal)
# permBBH = np.random.permutation(nTotal)
# permSG  = np.random.permutation(nTotal)
# permGLITCH = np.random.permutation(len(realglitch_trimmed))

# np.savetxt("../Data_cached/SupLearn/permDNN_BKG_2.dat", permBKG)
# np.savetxt("../Data_cached/SupLearn/permDNN_BBH_2.dat", permBBH)
# np.savetxt("../Data_cached/SupLearn/permDNN_SG_2.dat", permSG)
# np.savetxt("../Data_cached/SupLearn/permDNN_GLITCH_2.dat", permGLITCH)

permBKG = np.genfromtxt("../Data_cached/SupLearn/permDNN_BKG_2.dat").astype(int)
permBBH = np.genfromtxt("../Data_cached/SupLearn/permDNN_BBH_2.dat").astype(int)
permSG = np.genfromtxt("../Data_cached/SupLearn/permDNN_SG_2.dat").astype(int)
permGLITCH = np.genfromtxt("../Data_cached/SupLearn/permDNN_GLITCH_2.dat").astype(int)

# initializing the training set
X_train[ : nTrain] = realbbh_trimmed[permBBH[:nTrain]]
X_train[nTrain : nTrain+nTrain_ns] = realbkg_trimmed[permBKG[:nTrain_ns]]
X_train[nTrain+nTrain_ns : nTrain+2*nTrain_ns] = realsg_trimmed[permSG[:nTrain_ns]]
X_train[nTrain+2*nTrain_ns : ] = realglitch_trimmed[permGLITCH[:nTrain_g]]

target_train[:nTrain] = 1;

# initializing the test set
X_test[ : nTest] = realbbh_trimmed[permBBH[-nTest:]]
X_test[nTest : nTest+nTest_ns] = realbkg_trimmed[permBKG[-nTest_ns:]]
X_test[nTest+nTest_ns : nTest+2*nTest_ns] = realsg_trimmed[permSG[-nTest_ns:]]
X_test[nTest+2*nTest_ns : ] = realglitch_trimmed[permGLITCH[-nTest_g:]]

target_test[:nTest] = 1;

# initializing the validation set
X_valid[:nValid] = realbbh_trimmed[permBBH[nTrain : -nTest]]
X_valid[nValid : nValid+nValid_ns] = realbkg_trimmed[permBKG[nTrain_ns : nTrain_ns+nValid_ns]]
X_valid[nValid+nValid_ns : nValid+2*nValid_ns] = realsg_trimmed[permSG[nTrain_ns : nTrain_ns+nValid_ns]]
X_valid[nValid+2*nValid_ns : ] = realglitch_trimmed[permGLITCH[nTrain_g : nTrain_g+nValid_g]]

target_valid[:nValid] = 1;

train_dataset = TensorDataset(torch.FloatTensor(X_train.reshape((X_train.shape[0], X_train.shape[1]))), torch.FloatTensor(target_train.reshape((len(target_train)),1)))
test_dataset  = TensorDataset(torch.FloatTensor(X_test.reshape((X_test.shape[0], X_test.shape[1]))),  torch.FloatTensor(target_test.reshape((len(target_test)),1)))
valid_dataset = TensorDataset(torch.FloatTensor(X_valid.reshape((X_valid.shape[0], X_valid.shape[1]))), torch.FloatTensor(target_valid.reshape((len(target_valid)),1)))

trainDataLoader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
validationDataLoader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=True)

# %%
outputTest = classifier(torch.FloatTensor(X_test))
resTest = torch.argmax(nn.Softmax(dim=1)(outputTest), dim=1)
resTest_beforeSM = nn.Softmax(dim = 1)(outputTest).detach().numpy()

# %%
classifier
# Out:
# SLDNN(
#   (fc1): Linear(in_features=200, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=4, bias=True)
#   (act): ReLU()
# )

# %%
resTest
# Out:
# tensor([1, 1, 1,  ..., 0, 0, 0])

# %%
plt.hist(resTest_beforeSM[:nTest][:,1], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : nTest+nTest_ns][:,1], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+nTest_ns:nTest+2 * nTest_ns][:,1], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+2 * nTest_ns:][:,1], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()

# %%
plt.hist(resTest_beforeSM[:nTest][:,1], histtype='step', label = 'noise', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest : nTest+nTest_ns][:,1], histtype='step', label = 'BBH', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+nTest_ns:nTest+2 * nTest_ns][:,1], histtype='step', label = 'sinegaussian', bins = bins, density=True)
plt.hist(resTest_beforeSM[nTest+2 * nTest_ns:][:,1], histtype='step', label = 'glitch', bins = bins, density=True)
plt.legend()
plt.show()

TPR_list = upperTPRFPRcalc(resTest_beforeSM[nTest:][:,1].flatten(), resTest_beforeSM[:nTest][:,1].flatten(), FPR_list)
plt.plot(FPR_list, TPR_list, label = 'auc = ' + str(auc(FPR_list, TPR_list)))
plt.xscale('log')
plt.ylim(0,1.1)
plt.legend()
plt.show()
# Out:
# 20000
# 20000

# %%
np.argwhere(resTest[:nTest] == 1).shape[1]
# Out:
# 17577

# %%
(np.argwhere(resTest[:nTest] == 1).shape[1] + np.argwhere(resTest[nTest:] != 1).shape[1]) / (2 * nTest)
# Out:
# 0.89955

# %% [markdown]
# ### 200-64-64-16-4

# %%
class SLDNN(nn.Module):
    def __init__(self):
        super(SLDNN, self).__init__()
        self.fc1 = nn.Linear(200, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 16)
        self.output = nn.Linear(16, 4)
        self.act = nn.ReLU()

    def forward(self, x):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.act(self.fc3(x))
        
        # CrossEntropyLoss apply softmax automatically
        return self.output(x)
    
#         x = self.sig(self.fc3(x))
#         return x

# %%
classifier = SLDNN().cuda()

print(sum(p.numel() for p in classifier.parameters() if p.requires_grad))

optimizer = optim.Adam(classifier.parameters(), lr=0.00005)
loss_func = nn.CrossEntropyLoss().cuda()
loss_train = np.empty((epochs, ))
loss_validation = np.empty((epochs, ))

for epoch in range(epochs):

    t0 = time.time()
    classifier.train()
    for batchidx, (x, tgt_index) in enumerate(trainDataLoader):
        x = x.cuda()
        tgt_index = tgt_index.cuda()
        output = classifier(x)
        loss = loss_func(output, tgt_index)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    classifier.eval()
    with torch.no_grad():
        val_loss = 0
        n_correct = 0;
        for batchidx, (x, tgt_index) in enumerate(validationDataLoader):
            x = x.cuda()
            tgt_index = tgt_index.cuda()
            output = classifier(x)
            lossVal = loss_func(output, tgt_index)
            val_loss += lossVal.item()
            n_correct += torch.eq(tgt_index, torch.argmax(output, dim=1)).sum().item()

        val_loss /= len(validationDataLoader)

    loss_train[epoch] = loss.item()
    loss_validation[epoch] = val_loss
    print('Epoch: %04d, Training loss=%f, Validation loss=%f, valid accuracy=%f' % (epoch+1, loss_train[epoch], val_loss, n_correct*1./len(X_valid)))
    print(time.time() - t0)

#     print(time.time() - t0)
torch.save(classifier.cuda(), "../data/SupLearn/Classifier_64-64-16.pt")
np.savetxt("../data/SupLearn/lossClassifierTraining_64-64-16.dat", [loss_train, loss_validation])
# Out:
# 18132
# Epoch: 0001, Training loss=0.474716, Validation loss=0.742357, valid accuracy=0.666301
# 19.324056386947632
# Epoch: 0002, Training loss=0.374694, Validation loss=0.680511, valid accuracy=0.710719
# 18.770312786102295
# Epoch: 0003, Training loss=0.670147, Validation loss=0.638941, valid accuracy=0.732686
# 26.299160957336426
# Epoch: 0004, Training loss=1.250036, Validation loss=0.613479, valid accuracy=0.747782
# 25.375213623046875
# Epoch: 0005, Training loss=0.738831, Validation loss=0.598099, valid accuracy=0.755072
# 24.368035554885864
# Epoch: 0006, Training loss=0.144531, Validation loss=0.584319, valid accuracy=0.763653
# 26.16805338859558
# Epoch: 0007, Training loss=0.956067, Validation loss=0.573101, valid accuracy=0.768459
# 22.840923309326172
# Epoch: 0008, Training loss=0.247889, Validation loss=0.559672, valid accuracy=0.771911
# 17.952731370925903
# Epoch: 0009, Training loss=0.985831, Validation loss=0.545236, valid accuracy=0.777846
# 19.1991286277771
# Epoch: 0010, Training loss=0.119106, Validation loss=0.527809, valid accuracy=0.784620
# 18.968391180038452
# Epoch: 0011, Training loss=0.369052, Validation loss=0.511327, valid accuracy=0.793136
# 18.224614143371582
# Epoch: 0012, Training loss=0.470067, Validation loss=0.493350, valid accuracy=0.801264
# 20.77284574508667
# Epoch: 0013, Training loss=0.558160, Validation loss=0.478381, valid accuracy=0.807974
# 24.378840446472168
# Epoch: 0014, Training loss=0.128317, Validation loss=0.465933, valid accuracy=0.813587
# 20.513184070587158
# Epoch: 0015, Training loss=0.094866, Validation loss=0.456895, valid accuracy=0.815877
# 19.931824207305908
# Epoch: 0016, Training loss=0.259515, Validation loss=0.447650, valid accuracy=0.821393
# 17.62424635887146
# Epoch: 0017, Training loss=0.702099, Validation loss=0.440269, valid accuracy=0.825425
# 17.18064570426941
# Epoch: 0018, Training loss=0.413458, Validation loss=0.432936, valid accuracy=0.828457
# 17.306644678115845
# Epoch: 0019, Training loss=0.277333, Validation loss=0.425494, valid accuracy=0.831264
# 17.35526704788208
# 22.346779823303223
# Epoch: 0193, Training loss=0.033740, Validation loss=0.323562, valid accuracy=0.885262
# 18.526077270507812
# Epoch: 0194, Training loss=0.037982, Validation loss=0.321696, valid accuracy=0.885810
# 17.596664428710938
# Epoch: 0195, Training loss=0.972785, Validation loss=0.321544, valid accuracy=0.885907
# 17.340532541275024
# Epoch: 0196, Training loss=0.002988, Validation loss=0.323328, valid accuracy=0.884488
# 17.734508991241455
# Epoch: 0197, Training loss=0.015251, Validation loss=0.322300, valid accuracy=0.885584
# 18.329631805419922
# Epoch: 0198, Training loss=0.234889, Validation loss=0.323468, valid accuracy=0.885617
# 16.66358208656311
# Epoch: 0199, Training loss=0.084534, Validation loss=0.321133, valid accuracy=0.885875
# 16.977046489715576
# Epoch: 0200, Training loss=0.085306, Validation loss=0.321967, valid accuracy=0.885068
# 21.728718280792236

# %%
plt.plot(loss_train)
plt.plot(loss_validation)

# %%
classifier.eval()
classifier.cpu()
# Out:
# SLDNN(
#   (fc1): Linear(in_features=200, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=4, bias=True)
#   (act): ReLU()
# )

# %%
outputTest = nn.Softmax(dim=1)(classifier(torch.FloatTensor(X_test)))

# %%
resTest = torch.argmax(outputTest, dim=1)

# %%
print(torch.eq(torch.tensor(target_test), resTest).sum().item())
print(torch.eq(torch.tensor(target_test), resTest).sum().item() / len(target_test))
# Out:
# 54902
# 0.8855304117808351

# %%
print(len(target_test) - torch.eq(torch.tensor(target_test>1), resTest<=1).sum().item())
print(1 - torch.eq(torch.tensor(target_test>1), resTest<=1).sum().item() / len(target_test))
# Out:
# 55661
# 0.8977725447184632

# %%
foo = outputTest.detach().numpy()

# %%
def calcROCPoint(index, threshold):
    nTotalSignal = np.sum(target_test==index)
    nTotalBKG = len(target_test) - nTotalSignal;
    
    nTP = np.sum(np.logical_and(target_test==index, foo[:, index]>threshold));
#     nFN = nTotalSignal - nTP;
    nFP = np.sum(np.logical_and(target_test!=index, foo[:, index]>threshold));
#     nTN = nTotalBKG - nFP;
    
    return [nFP/nTotalBKG, nTP/nTotalSignal]

# %%
bar = plt.hist(foo[target_test==1, 1])
bar = plt.hist(foo[target_test!=1, 1])

# %%
sig_type = ["glitch", "noise", "bbh", "sg"]
for ind in range(4):
    bar = np.array([calcROCPoint(ind, 1-0.01*i) for i in range(101)])
    plt.plot(bar[:, 0], bar[:, 1], label=sig_type[ind])
    
plt.plot(np.linspace(0, 1, 2), np.linspace(0, 1, 2), 'k--')
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.legend()
plt.savefig("../results/SupLearnROC_64-64-16.jpg")

# %% [markdown]
# ### 200-64-16-3

# %%
class SLDNN(nn.Module):
    def __init__(self):
        super(SLDNN, self).__init__()
        self.fc1 = nn.Linear(200, 64)
        self.fc2 = nn.Linear(64, 8)
#         self.fc3 = nn.Linear(64, 16)
        self.output = nn.Linear(8, 3)
        self.act = nn.ReLU()

    def forward(self, x):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
#         x = self.act(self.fc3(x))
        
        # CrossEntropyLoss apply softmax automatically
        return self.output(x)
    
#         x = self.sig(self.fc3(x))
#         return x

# %%
classifier = SLDNN().cuda()

print(sum(p.numel() for p in classifier.parameters() if p.requires_grad))

optimizer = optim.Adam(classifier.parameters(), lr=0.00005)
loss_func = nn.CrossEntropyLoss().cuda()
loss_train = np.empty((epochs, ))
loss_validation = np.empty((epochs, ))

for epoch in range(epochs):

    t0 = time.time()
    classifier.train()
    for batchidx, (x, tgt_index) in enumerate(trainDataLoader):
        x = x.cuda()
        tgt_index = tgt_index.cuda()
        output = classifier(x)
        loss = loss_func(output, tgt_index)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    classifier.eval()
    with torch.no_grad():
        val_loss = 0
        n_correct = 0;
        for batchidx, (x, tgt_index) in enumerate(validationDataLoader):
            x = x.cuda()
            tgt_index = tgt_index.cuda()
            output = classifier(x)
            lossVal = loss_func(output, tgt_index)
            val_loss += lossVal.item()
            n_correct += torch.eq(tgt_index, torch.argmax(output, dim=1)).sum().item()

        val_loss /= len(validationDataLoader)

    loss_train[epoch] = loss.item()
    loss_validation[epoch] = val_loss
    print('Epoch: %04d, Training loss=%f, Validation loss=%f, valid accuracy=%f' % (epoch+1, loss_train[epoch], val_loss, n_correct*1./len(X_valid)))
    print(time.time() - t0)

#     print(time.time() - t0)
# Out:
# 13955
# Epoch: 0001, Training loss=0.238310, Validation loss=0.402856, valid accuracy=0.853271
# 5.0875935554504395
# Epoch: 0002, Training loss=0.366897, Validation loss=0.300676, valid accuracy=0.888675
# 5.088829278945923
# Epoch: 0003, Training loss=0.073103, Validation loss=0.249080, valid accuracy=0.909433
# 5.2581586837768555
# Epoch: 0004, Training loss=0.199646, Validation loss=0.223287, valid accuracy=0.919390
# 5.296870946884155
# Epoch: 0005, Training loss=0.655912, Validation loss=0.209474, valid accuracy=0.923387
# 5.280154466629028
# Epoch: 0006, Training loss=0.244343, Validation loss=0.201741, valid accuracy=0.925348
# 5.284854412078857
# Epoch: 0007, Training loss=0.063807, Validation loss=0.195739, valid accuracy=0.928615
# 5.273844242095947
# Epoch: 0008, Training loss=0.103479, Validation loss=0.191723, valid accuracy=0.929000
# 5.277575254440308
# Epoch: 0009, Training loss=0.068603, Validation loss=0.188761, valid accuracy=0.931229
# 5.318134546279907
# Epoch: 0010, Training loss=0.075587, Validation loss=0.185413, valid accuracy=0.932190
# 5.267415761947632
# Epoch: 0011, Training loss=0.264596, Validation loss=0.183158, valid accuracy=0.932998
# 5.2992026805877686
# Epoch: 0012, Training loss=0.032410, Validation loss=0.180780, valid accuracy=0.935419
# 5.263878583908081
# Epoch: 0013, Training loss=0.316269, Validation loss=0.179221, valid accuracy=0.935381
# 5.28216552734375
# Epoch: 0014, Training loss=0.172294, Validation loss=0.178062, valid accuracy=0.935304
# 5.279782056808472
# Epoch: 0015, Training loss=0.562289, Validation loss=0.176018, valid accuracy=0.936227
# 5.254773378372192
# Epoch: 0016, Training loss=0.109607, Validation loss=0.175855, valid accuracy=0.936611
# 5.258839845657349
# Epoch: 0017, Training loss=0.020162, Validation loss=0.174959, valid accuracy=0.936726
# 5.300735712051392
# Epoch: 0190, Training loss=0.023408, Validation loss=0.252077, valid accuracy=0.938687
# 5.2963361740112305
# Epoch: 0191, Training loss=0.004783, Validation loss=0.253743, valid accuracy=0.938495
# 5.308973073959351
# Epoch: 0192, Training loss=0.047022, Validation loss=0.252771, valid accuracy=0.938572
# 5.2956249713897705
# Epoch: 0193, Training loss=0.110445, Validation loss=0.254462, valid accuracy=0.938072
# 5.310439109802246
# Epoch: 0194, Training loss=0.044426, Validation loss=0.256664, valid accuracy=0.938341
# 5.307866811752319
# Epoch: 0195, Training loss=0.117208, Validation loss=0.254752, valid accuracy=0.938725
# 5.306440353393555
# Epoch: 0196, Training loss=0.002604, Validation loss=0.256582, valid accuracy=0.938802
# 5.296403884887695
# Epoch: 0197, Training loss=0.028691, Validation loss=0.257290, valid accuracy=0.938187
# 5.331668376922607
# Epoch: 0198, Training loss=0.067665, Validation loss=0.258325, valid accuracy=0.939110
# 5.30853271484375
# Epoch: 0199, Training loss=0.001565, Validation loss=0.259200, valid accuracy=0.938495
# 5.378114223480225
# Epoch: 0200, Training loss=0.002470, Validation loss=0.258944, valid accuracy=0.938110
# 5.328522443771362
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 44
#      41     print(time.time() - t0)
#      43 #     print(time.time() - t0)
# ---> 44 torch.save(classifier.cuda(), "../data/SupLearn/Classifier.pt")
#      45 np.savetxt("../data/SupLearn/lossClassifierTraining.dat", [loss_train, loss_validation])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\serialization.py:628, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     625 _check_save_filelike(f)
#     627 if _use_new_zipfile_serialization:
# --> 628     with _open_zipfile_writer(f) as opened_zipfile:
#     629         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     630         return
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\serialization.py:502, in _open_zipfile_writer(name_or_buffer)
#     500 else:
#     501     container = _open_zipfile_writer_buffer
# --> 502 return container(name_or_buffer)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\serialization.py:473, in _open_zipfile_writer_file.__init__(self, name)
#     471     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     472 else:
# --> 473     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory ../data/SupLearn does not exist.

# %%
torch.save(classifier.cuda(), "../Data_cached/SupLearn/Classifier.pt")
np.savetxt("../Data_cached/SupLearn/lossClassifierTraining.dat", [loss_train, loss_validation])

# %%
plt.plot(loss_train)
plt.plot(loss_validation)

# %%
classifier.cpu()
# Out:
# SLDNN(
#   (fc1): Linear(in_features=200, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=4, bias=True)
#   (act): ReLU()
# )

# %%
X_train.shape
# Out:
# (216998, 200)

# %%
outputTest = classifier(torch.FloatTensor(X_test))

# %%
resTest = torch.argmax(nn.Softmax(dim=1)(outputTest), dim=1)

# %%
resTest
# Out:
# tensor([1, 1, 1,  ..., 3, 1, 0])

# %%
target_test
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
print(torch.eq(torch.tensor(target_test), resTest).sum().item())
print(torch.eq(torch.tensor(target_test), resTest).sum().item() / len(target_test))
# Out:
# 54037
# 0.8715785738479653

# %%
print(len(target_test) - torch.eq(torch.tensor(target_test>1), resTest<=1).sum().item())
print(1 - torch.eq(torch.tensor(target_test>1), resTest<=1).sum().item() / len(target_test))
# Out:
# 55029
# 0.8875788319166438
